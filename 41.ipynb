# %% [markdown]
# The formula for calculating the sample mean (average) is as follows:
#
# Mean
# =
# ∑
# �
# =
# 1
# �
# �
# �
# �
# Mean=
# n
# ∑
# i=1
# n
# ​
#  x
# i
# ​
#
# ​
#
#
# Where:
#
# Mean
# Mean is the sample mean (average).
# �
# �
# x
# i
# ​
#   represents each individual data point in the dataset.
# �
# n is the number of data points in the sample.
# Here's an example calculation of the sample mean for a dataset:
#
# Dataset: [10, 15, 20, 25, 30]
#
# Calculation:
#
# Add up all the data points:
# ∑
# �
# =
# 1
# 5
# �
# �
# =
# 10
# +
# 15
# +
# 20
# +
# 25
# +
# 30
# =
# 100
# ∑
# i=1
# 5
# ​
#  x
# i
# ​
#  =10+15+20+25+30=100
#
# Determine the number of data points (
# �
# n): In this example,
# �
# =
# 5
# n=5 because there are five data points in the dataset.
#
# Use the formula to calculate the sample mean:
# Mean
# =
# ∑
# �
# =
# 1
# �
# �
# �
# �
# =
# 100
# 5
# =
# 20
# Mean=
# n
# ∑
# i=1
# n
# ​
#  x
# i
# ​
#
# ​
#  =
# 5
# 100
# ​
#  =20
#
# So, the sample mean (average) for the dataset [10, 15, 20, 25, 30] is 20.
